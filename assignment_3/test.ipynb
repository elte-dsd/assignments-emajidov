# %%
from DynamicWeightedMajority import DynamicWeightedMajority
from Stagger import Stagger
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from matplotlib import pyplot as plt
import numpy as np

# %%
stagger = Stagger(120) 
x_train, y_train = stagger.generateData() 
x_test, y_test = stagger.generateData()

# %%
dwm =  DynamicWeightedMajority(0.5,0.01,6)

# %%
size, accs, nb_accs = dwm.fit(x_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)th Expert Weight: 0.5
# GaussianNB(priors=None, var_smoothing=1e-09)th Expert Weight: 0.25
# GaussianNB(priors=None, var_smoothing=1e-09)th Expert Weight: 0.5
# GaussianNB(priors=None, var_smoothing=1e-09)th Expert Weight: 0.125
# GaussianNB(priors=None, var_smoothing=1e-09)th Expert Weight: 0.25
# GaussianNB(priors=None, var_smoothing=1e-09)th Expert Weight: 0.0625
# GaussianNB(priors=None, var_smoothing=1e-09)th Expert Weight: 0.125
# GaussianNB(priors=None, var_smoothing=1e-09)th Expert Weight: 0.03125
# GaussianNB(priors=None, var_smoothing=1e-09)th Expert Weight: 0.0625
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
plt.figure(1, figsize=(16,10))
plt.title("Acurracies")
plt.plot(np.arange(len(accs)), accs, label="DWM")
plt.legend()

plt.title("Acurracies")
plt.plot(np.arange(len(nb_accs)), nb_accs, label="Simpe NB")
plt.legend()
plt.show()

# %%
plt.figure(1, figsize=(16,10))
plt.title("Experts")
plt.plot(np.arange(len(size)), size)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
nb = GaussianNB()

# %%
nb.fit(x_train, y_train)
# Out:
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
preds = nb.predict(x_test)
nb_acc = accuracy_score(y_test, preds)
print(nb_acc)
# Out:
# 0.7166666666666667

# %%
dwm_preds = dwm.predict(x_test)
dwm_acc = accuracy_score(y_test, dwm_preds)
print(dwm_acc)
# Out:
# 0.6916666666666667
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:436: RuntimeWarning: divide by zero encountered in log
#   n_ij = - 0.5 * np.sum(np.log(2. * np.pi * self.sigma_[i, :]))
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:438: RuntimeWarning: divide by zero encountered in true_divide
#   (self.sigma_[i, :]), 1)
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:438: RuntimeWarning: invalid value encountered in true_divide
#   (self.sigma_[i, :]), 1)
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:438: RuntimeWarning: invalid value encountered in subtract
#   (self.sigma_[i, :]), 1)
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:436: RuntimeWarning: divide by zero encountered in log
#   n_ij = - 0.5 * np.sum(np.log(2. * np.pi * self.sigma_[i, :]))
# ...

# %%
dwm = DynamicWeightedMajority(0.5,0.01,50)

# %%
sizes, accs, nb_accs = dwm.fit(x_train, y_train)
# Out:
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:435: RuntimeWarning: divide by zero encountered in log
#   jointi = np.log(self.class_prior_[i])
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:436: RuntimeWarning: divide by zero encountered in log
#   n_ij = - 0.5 * np.sum(np.log(2. * np.pi * self.sigma_[i, :]))
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:438: RuntimeWarning: divide by zero encountered in true_divide
#   (self.sigma_[i, :]), 1)
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:438: RuntimeWarning: invalid value encountered in true_divide
#   (self.sigma_[i, :]), 1)
# ...

# %%
plt.figure(1, figsize=(16,10))
plt.title("Acurracies")
plt.plot(np.arange(len(accs)), accs, label="DWM")
plt.legend()

plt.title("Acurracies")
plt.plot(np.arange(len(nb_accs)), nb_accs, label="Simpe NB")
plt.legend()
plt.show()

# %%
plt.figure(1, figsize=(16,10))
plt.title("Experts")
plt.plot(np.arange(len(size)), size)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
from skmultiflow.data.sea_generator import SEAGenerator

# %%
stream = SEAGenerator(classification_function = , random_state = 112, balance_classes = False, noise_percentage = 0.28)

# %%
stream.prepare_for_use()

# %%
dwm = DynamicWeightedMajority(0.5,0.01,50)
dwm_accs = []
nb_accs = [] 
sizes = [] 
while(stream.has_more_samples()):
    data = stream.next_sample(10)
    size, dwm_acc, nb_acc = dwm.fit(data[0], data[1])
    for i in size: 
        sizes.append(i) 
    for i in dwm_acc:
        dwm_accs.append(i)
    for i in nb_acc: 
        nb_accs.append(i)
# Out:
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:436: RuntimeWarning: divide by zero encountered in log
#   n_ij = - 0.5 * np.sum(np.log(2. * np.pi * self.sigma_[i, :]))
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:438: RuntimeWarning: divide by zero encountered in true_divide
#   (self.sigma_[i, :]), 1)
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:438: RuntimeWarning: invalid value encountered in subtract
#   (self.sigma_[i, :]), 1)
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:435: RuntimeWarning: divide by zero encountered in log
#   jointi = np.log(self.class_prior_[i])
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:436: RuntimeWarning: divide by zero encountered in log
#   n_ij = - 0.5 * np.sum(np.log(2. * np.pi * self.sigma_[i, :]))
# C:\Users\Elgun\Anaconda3\lib\site-packages\sklearn\naive_bayes.py:438: RuntimeWarning: divide by zero encountered in true_divide
# ...

# %%
plt.figure(1, figsize=(16,10))
plt.title("Acurracies")
plt.plot(np.arange(len(dwm_accs)), dwm_accs, label="DWM")
plt.legend()

plt.title("Acurracies")
plt.plot(np.arange(len(nb_accs)), nb_accs, label="Simpe NB")
plt.legend()
plt.show()
